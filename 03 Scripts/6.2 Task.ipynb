# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %% [markdown]
# # Importing Dataframe

# %%
path = r'/Users/hollyringsak/Documents/6.1 KCA House Data'
df = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'kc_house_data_clean.csv'), index_col= False)

# %% [markdown]
# # Correlation Matrix

# %%
df.head()
# Out:
#    Unnamed: 0          id                 date     price  bedrooms  bathrooms  \
# 0           0  7129300520  1413158400000000000  221900.0         3       1.00
# 1           1  6414100192  1418083200000000000  538000.0         3       2.25
# 2           2  5631500400  1424822400000000000  180000.0         2       1.00
# 3           3  2487200875  1418083200000000000  604000.0         4       3.00
# 4           4  1954400510  1424217600000000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.corr()
# Out:
#                Unnamed: 0        id      date     price  bedrooms  bathrooms  \
# Unnamed: 0       1.000000  0.006747 -0.000763  0.027362  0.009831   0.107354
# id               0.006747  1.000000  0.005538 -0.016753  0.002461   0.005144
# date            -0.000763  0.005538  1.000000 -0.004343 -0.015524  -0.034435
# price            0.027362 -0.016753 -0.004343  1.000000  0.315445   0.525147
# bedrooms         0.009831  0.002461 -0.015524  0.315445  1.000000   0.529159
# bathrooms        0.107354  0.005144 -0.034435  0.525147  0.529159   1.000000
# sqft_living      0.044737 -0.012276 -0.034586  0.702047  0.591467   0.754663
# sqft_lot        -0.026869 -0.132118  0.006302  0.089664  0.032807   0.087735
# floors           0.179179  0.018494 -0.022539  0.256811  0.181085   0.500645
# waterfront      -0.007608 -0.002724  0.001351  0.266371 -0.006611   0.063742
# view            -0.013739  0.011582 -0.001816  0.397299  0.081930   0.187732
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=8, rotation=45) # x =xis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=8) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
plt.savefig("correlation_matrix.png")

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# '/Users/hollyringsak/Library/CloudStorage/OneDrive-Personal/Documents/Achievement 6'

# %%
# Change directory
os.chdir('/Users/hollyringsak/Documents/6.1 KCA House Data/04 Analysis/Visualizations')

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/hollyringsak/Documents/6.1 KCA House Data/04 Analysis/Visualizations'

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['price', 'bedrooms', 'bathrooms', 'floors','sqft_living', 'sqft_lot', 'view','condition', 'grade']]

# %%
sub
# Out:
#           price  bedrooms  bathrooms  floors  sqft_living  sqft_lot  view  \
# 0      221900.0         3       1.00     1.0         1180      5650     0
# 1      538000.0         3       2.25     2.0         2570      7242     0
# 2      180000.0         2       1.00     1.0          770     10000     0
# 3      604000.0         4       3.00     1.0         1960      5000     0
# 4      510000.0         3       2.00     1.0         1680      8080     0
# ...         ...       ...        ...     ...          ...       ...   ...
# 21607  360000.0         3       2.50     3.0         1530      1131     0
# 21608  400000.0         4       2.50     2.0         2310      5813     0
# 21609  402101.0         2       0.75     2.0         1020      1350     0
# 21610  400000.0         3       2.50     2.0         1600      2388     0
# 21611  325000.0         2       0.75     2.0         1020      1076     0
#
#        condition  grade
# 0              3      7
# 1              3      7
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(7,7))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ## Looking at the price variable we can see that sqft_living and grade have the highest positive correlation. Sqft_lot and condition have the lowest correlation.

# %% [markdown]
# # Scatterplot

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'sqft_living', y = 'price', data = df)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Scatterplot shows a positive correlation between price and sqft_living

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'grade', y = 'price', data = df)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Grade and price also have a somewhat positive correlation

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'sqft_lot', y = 'price', data = df)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Hard to distinguish a correlation

# %% [markdown]
# # Pair Plots

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['sqft_living', 'grade', 'condition', 'price']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Positive correlation between price and sqft_living, & price and grade. No correlation between condition and any other variables. Curious why grade has a correlation with price but not condition.

# %% [markdown]
# # Categorical plots

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the price ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['price'], bins = 20, kde = True)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
df.loc[df['price'] < 400000, 'Price category'] = 'Low price'

# %%
df.loc[(df['price'] >= 400000) & (df['price'] < 600000), 'Price category'] = 'Middle price'

# %%
df.loc[df['price'] >= 600000, 'Price category'] = 'High price'

# %%
df['Price category'].value_counts(dropna = False)
# Out:
# Price category
# Low price       8694
# Middle price    6553
# High price      6365
# Name: count, dtype: int64

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="sqft_living", y="price", hue="Price category", data=df)
# Out:
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/hollyringsak/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# fig = g.get_figure()
g.savefig("categorical_plot.png")

# %% [markdown]
# ## The categorical plot again proves the positive correlation between sqft_living and price

# %% [markdown]
# ## •	What variables have a higher/lower impact on determining the value?

# %% [markdown]
# sqft_living and grade have the highest positive correlation to the price

# %% [markdown]
# ## I hypothesize sqft_living will be the main factor in determining prices of homes. I also hypothesize that there will be a correlation between sqft_living and sqft_living15 as homes will be collected into richer neighborhoods.
